# %%
import os

file_path = r'E:\ai\frame_image\punching\croki/'
file_list = os.listdir(file_path)
print(file_list)
# Out:
# ['croki_11_7_frame12.png', 'croki_11_7_frame12.txt', 'croki_11_7_frame13.png', 'croki_11_7_frame13.txt', 'croki_11_7_frame14.png', 'croki_11_7_frame14.txt', 'croki_11_8_frame1.png', 'croki_11_8_frame1.txt', 'croki_11_8_frame15.png', 'croki_11_8_frame15.txt', 'croki_11_8_frame22.png', 'croki_11_8_frame22.txt', 'croki_12_2_frame10.png', 'croki_12_2_frame10.txt', 'croki_12_3_frame74.png', 'croki_12_3_frame74.txt', 'croki_17_2_frame1.png', 'croki_17_2_frame1.txt', 'croki_17_2_frame3.png', 'croki_17_2_frame3.txt', 'croki_17_2_frame4.png', 'croki_17_2_frame4.txt', 'croki_1_1_frame0.png', 'croki_1_1_frame0.txt', 'croki_1_1_frame11.png', 'croki_1_1_frame11.txt', 'croki_1_1_frame14.png', 'croki_1_1_frame14.txt', 'croki_1_1_frame19.png', 'croki_1_1_frame19.txt', 'croki_1_1_frame21.png', 'croki_1_1_frame21.txt', 'croki_1_1_frame3.png', 'croki_1_1_frame3.txt', 'croki_1_4_frame10.png', 'croki_1_4_frame10.txt', 'croki_1_4_frame13.png', 'croki_1_4_frame13.txt', 'croki_1_4_frame17.png', 'croki_1_4_f
# ...

# %%
for name in file_list:
    src = os.path.join(file_path, name)
    print(src)
    dst = 'punch_' + name
    dst = os.path.join(file_path, dst)
    print(dst)
    os.rename(src, dst)
# Out:
# E:\ai\frame_image\punching\croki/croki_11_7_frame12.png
# E:\ai\frame_image\punching\croki/punch_croki_11_7_frame12.png
# E:\ai\frame_image\punching\croki/croki_11_7_frame12.txt
# E:\ai\frame_image\punching\croki/punch_croki_11_7_frame12.txt
# E:\ai\frame_image\punching\croki/croki_11_7_frame13.png
# E:\ai\frame_image\punching\croki/punch_croki_11_7_frame13.png
# E:\ai\frame_image\punching\croki/croki_11_7_frame13.txt
# E:\ai\frame_image\punching\croki/punch_croki_11_7_frame13.txt
# E:\ai\frame_image\punching\croki/croki_11_7_frame14.png
# E:\ai\frame_image\punching\croki/punch_croki_11_7_frame14.png
# E:\ai\frame_image\punching\croki/croki_11_7_frame14.txt
# E:\ai\frame_image\punching\croki/punch_croki_11_7_frame14.txt
# E:\ai\frame_image\punching\croki/croki_11_8_frame1.png
# E:\ai\frame_image\punching\croki/punch_croki_11_8_frame1.png
# E:\ai\frame_image\punching\croki/croki_11_8_frame1.txt
# E:\ai\frame_image\punching\croki/punch_croki_11_8_frame1.txt
# ...

# %%
file_list = os.listdir(file_path)
print(file_list)
# Out:
# ['punch_croki_11_7_frame12.png', 'punch_croki_11_7_frame12.txt', 'punch_croki_11_7_frame13.png', 'punch_croki_11_7_frame13.txt', 'punch_croki_11_7_frame14.png', 'punch_croki_11_7_frame14.txt', 'punch_croki_11_8_frame1.png', 'punch_croki_11_8_frame1.txt', 'punch_croki_11_8_frame15.png', 'punch_croki_11_8_frame15.txt', 'punch_croki_11_8_frame22.png', 'punch_croki_11_8_frame22.txt', 'punch_croki_12_2_frame10.png', 'punch_croki_12_2_frame10.txt', 'punch_croki_12_3_frame74.png', 'punch_croki_12_3_frame74.txt', 'punch_croki_17_2_frame1.png', 'punch_croki_17_2_frame1.txt', 'punch_croki_17_2_frame3.png', 'punch_croki_17_2_frame3.txt', 'punch_croki_17_2_frame4.png', 'punch_croki_17_2_frame4.txt', 'punch_croki_1_1_frame0.png', 'punch_croki_1_1_frame0.txt', 'punch_croki_1_1_frame11.png', 'punch_croki_1_1_frame11.txt', 'punch_croki_1_1_frame14.png', 'punch_croki_1_1_frame14.txt', 'punch_croki_1_1_frame19.png', 'punch_croki_1_1_frame19.txt', 'punch_croki_1_1_frame21.png', 'punch_croki_1_1_frame21
# ...
