Desktop\\punch_labeling_608\\data\\images\\kick_croki_11_0_frame24.txt', 'C:\\Users\\jaehy\\Desktop\\punch_labeling_608\\data\\images\\kick_croki_11_0_frame5.txt', 'C:\\Users\\jaehy\\Desktop\\punch_labeling_608\\data\\images\\kick_croki_11_1_frame14.txt', 'C:\\Users\\jaehy\\Desktop\\punch_labeling_608\\data\\images\\kick_croki_11_1_frame15.txt', 'C:\\Users\\jaehy\\Desktop\\punch_labeling_608\\data\\images\\kick_croki_11_1_frame7.txt', 'C:\\Users\\jaehy\\Desktop\\punch_labeling_608\\data\\images\\kick_croki_11_2_frame1.txt', 'C:\\Users\\jaehy\\Desktop\\punch_labeling_608\\data\\images\\kick_croki_11_2_frame16.txt', 'C:\\Users\\jaehy\\Desktop\\punch_labeling_608\\data\\images\\kick_croki_11_2_frame22.txt', 'C:\\Users\\jaehy\\Desktop\\punch_labeling_608\\data\\images\\kick_croki_11_2_frame5.txt', 'C:\\Users\\jaehy\\Desktop\\punch_labeling_608\\data\\images\\kick_croki_11_3_frame1.txt', 'C:\\Users\\jaehy\\Desktop\\punch_labeling_608\\data\\images\\kick_croki_11_3_frame2.txt', 'C:\\Users\\jaehy\\Desktop\\punch_labeling_608\\data\\images\\kick_croki_11_3_frame33.txt', 'C:\\Users\\jaehy\\Desktop\\punch_labeling_608\\data\\images\\kick_croki_11_3_frame34.txt', 'C:\\Users\\jaehy\\Desktop\\punch_labeling_608\\data\\images\\kick_croki_11_3_frame56.txt', 'C:\\Users\\jaehy\\Desktop\\punch_labeling_608\\data\\images\\kick_croki_11_4_frame1.txt', 'C:\\Users\\jaehy\\Desktop\\punch_labeling_608\\data\\images\\kick_croki_11_4_frame17.txt', 'C:\\Users\\jaehy\\Desktop\\punch_labeling_608\\data\\images\\kick_croki_11_4_frame18.txt', 'C:\\Users\\jaehy\\Desktop\\punch_labeling_608\\data\\ima ...

# %% [markdown]
# # threaten 삭제

# %%
# for file in file_list:
#     with open(file, 'r') as f:
#         lines = f.readlines()
#     with open(file, 'w') as f:
#         for line in lines:
#             index = int(list(line.split())[0])
#             if index != 7:
#                 f.write(line)

# %% [markdown]
# # pull 삭제

# %%
# for file in file_list:
#     with open(file, 'r') as f:
#         lines = f.readlines()
#     with open(file, 'w') as f:
#         for line in lines:
#             index = int(list(line.split())[0])
#             if index != 4:
#                 f.write(line)

# %% [markdown]
# # push falldown index 땡기기

# %%
# for file in file_list:
#     with open(file, 'r') as f:
#         lines = f.readlines()
#     with open(file, 'w') as f:
#         for line in lines:
#             tmp = list(line.split())
#             index = int(tmp[0])
#             if index == 5:
#                 tmp[0] = '4'
#                 f.write(' '.join(tmp)+'\n')
#             elif index == 6:
#                 tmp[0] = '5'
#                 f.write(' '.join(tmp) + '\n')
#             else:
#                 f.write(line)

# %% [markdown]
# # 빈 txt삭제

# %%
empty_cnt = 0
for file in file_list:
    isempty = os.stat(file).st_size == 0
    if isempty:
#         os.remove(file)
#         os.remove(file[:-3] + 'png')
        print(file)
        empty_cnt += 1
print(empty_cnt)
# Out:
# 0
