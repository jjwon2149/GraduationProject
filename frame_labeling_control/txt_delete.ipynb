# %%
from glob import glob
import os
path = r'D:\4\kick/'

file_list = glob(path + '*.txt')
# print(file_list)
for file in file_list:
    print(file)
    os.remove(file)
# Out:
# D:\4\kick\0_frame0.txt
# D:\4\kick\0_frame1.txt
# D:\4\kick\0_frame101.txt
# D:\4\kick\0_frame102.txt
# D:\4\kick\0_frame105.txt
# D:\4\kick\0_frame13.txt
# D:\4\kick\0_frame131.txt
# D:\4\kick\0_frame14.txt
# D:\4\kick\0_frame141.txt
# D:\4\kick\0_frame2.txt
# D:\4\kick\0_frame22.txt
# D:\4\kick\0_frame3.txt
# D:\4\kick\0_frame43.txt
# D:\4\kick\0_frame52.txt
# D:\4\kick\0_frame63.txt
# D:\4\kick\0_frame69.txt
# D:\4\kick\0_frame8.txt
# D:\4\kick\0_frame86.txt
# D:\4\kick\kick_croki_10_5_frame2.txt
# D:\4\kick\kick_croki_11_0_frame17.txt
# D:\4\kick\kick_croki_11_0_frame23.txt
# D:\4\kick\kick_croki_11_0_frame24.txt
# D:\4\kick\kick_croki_11_1_frame7.txt
# D:\4\kick\kick_croki_11_2_frame1.txt
# D:\4\kick\kick_croki_11_2_frame16.txt
# D:\4\kick\kick_croki_11_2_frame22.txt
# D:\4\kick\kick_croki_11_2_frame5.txt
# D:\4\kick\kick_croki_11_3_frame1.txt
# D:\4\kick\kick_croki_11_3_frame2.txt
# D:\4\kick\kick_croki_11_3_frame33.txt
# D:\4\kick\kick_croki_11_3_frame34.txt
# ...
